# %%
import IPython.display

# %% [markdown]
# # 作ったツール集
# - git_gistで公開しているツールはiPynb形式です
# - それ以外はWebアプリとして公開しています

# %% [markdown]
# ## 技マシン転売計算ツール
# - https://share.streamlit.io/sugimochi97/waza_machine_resale/app.py

# %% [markdown]
# ## 旅パのタイプ相性チェックツール
# - https://share.streamlit.io/sugimochi97/type_comp_app/app.py

# %% [markdown]
# # ネット上の活動

# %% [markdown]
# ## [Qiita](https://qiita.com/sugimochi_1019)

# %% [markdown]
# ### 1番LGTMが多い記事
#
# DockerでMinecraftサーバーを構築<br>
# - https://qiita.com/sugimochi_1019/items/c022277d48bf6eb398e6

# %% [markdown]
# ## [GitHub](https://github.com/sugimochi97)

# %% [markdown]
# ## [YouTube](https://www.youtube.com/channel/UCmoawejpvmLV3ZWvSPHzaKQ)

# %% [markdown]
# ### 最新の動画

# %%
IPython.display.YouTubeVideo('Lw_XBU0YM2c')

# %% [markdown]
# ### 最も再生数の多い動画

# %%
IPython.display.YouTubeVideo('tHWp0uJkdQc')

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/M7lc1UVf-VE" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" loading="lazy" allowfullscreen></iframe>
